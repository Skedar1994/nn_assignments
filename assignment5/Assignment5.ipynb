# %% [markdown]
# # Assignment 5
#
# **Submission deadline: last lab session before or on Tuesday, 09.5.17**
#
# **Points: 9 + 10 bonus points**
#
#
# ## Downloading this notebook
#
# This assignment is an Jupyter notebook. Download it by cloning https://github.com/janchorowski/nn_assignments. Follow the instructions in its README for instructions.
#
# For programming exerciese add your solutions to the notebook. For math exercies please provide us with answers on paper or type them in the notebook (it supports Latex-like equations).
#
# Please do not hesitate to use GitHub’s pull requests to send us corrections!

# %%
# %pylab inline
# Out:
# Vendor:  Continuum Analytics, Inc.
# Package: mkl
# Message: trial mode expires in 29 days
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Modular network implementation
#
# This assignment builds on code from Assignment 4, Problem 7.
# For your convenience, we have copied the code below. Please copy your solution from the old list, or fill in the blanks below to get a working network.
#
# In the following cells, I implement in a modular way a feedforward neural network. Please study the code - many network implementations follow a similar pattern.
#
# Please make sure that the network trains to nearly 100% accuracy on Iris.
#
# ## Task
#
# Your job is to implement SGD training on MNIST with the following elements:
# 1. SGD + momentum
# 2. weight decay
# 3. early stopping
#
# In overall, you should get below **2% testing errors**

# %%
#
# These are taken from https://github.com/mila-udem/blocks
# 

class Constant():
    """Initialize parameters to a constant.
    The constant may be a scalar or a :class:`~numpy.ndarray` of any shape
    that is broadcastable with the requested parameter arrays.
    Parameters
    ----------
    constant : :class:`~numpy.ndarray`
        The initialization value to use. Must be a scalar or an ndarray (or
        compatible object, such as a nested list) that has a shape that is
        broadcastable with any shape requested by `initialize`.
    """
    def __init__(self, constant):
        self._constant = numpy.asarray(constant)

    def generate(self, rng, shape):
        dest = numpy.empty(shape, dtype=np.float32)
        dest[...] = self._constant
        return dest


class IsotropicGaussian():
    """Initialize parameters from an isotropic Gaussian distribution.
    Parameters
    ----------
    std : float, optional
        The standard deviation of the Gaussian distribution. Defaults to 1.
    mean : float, optional
        The mean of the Gaussian distribution. Defaults to 0
    Notes
    -----
    Be careful: the standard deviation goes first and the mean goes
    second!
    """
    def __init__(self, std=1, mean=0):
        self._mean = mean
        self._std = std

    def generate(self, rng, shape):
        m = rng.normal(self._mean, self._std, size=shape)
        return m.astype(np.float32)


class Uniform():
    """Initialize parameters from a uniform distribution.
    Parameters
    ----------
    mean : float, optional
        The mean of the uniform distribution (i.e. the center of mass for
        the density function); Defaults to 0.
    width : float, optional
        One way of specifying the range of the uniform distribution. The
        support will be [mean - width/2, mean + width/2]. **Exactly one**
        of `width` or `std` must be specified.
    std : float, optional
        An alternative method of specifying the range of the uniform
        distribution. Chooses the width of the uniform such that random
        variates will have a desired standard deviation. **Exactly one** of
        `width` or `std` must be specified.
    """
    def __init__(self, mean=0., width=None, std=None):
        if (width is not None) == (std is not None):
            raise ValueError("must specify width or std, "
                             "but not both")
        if std is not None:
            # Variance of a uniform is 1/12 * width^2
            self._width = numpy.sqrt(12) * std
        else:
            self._width = width
        self._mean = mean

    def generate(self, rng, shape):
        w = self._width / 2
        m = rng.uniform(self._mean - w, self._mean + w, size=shape)
        return m.astype(np.float32)

# %%
class Layer(object):
    def __init__(self, rng=None):
        if rng is None:
            rng = numpy.random
        self.rng = rng
    
    @property
    def parameters(self):
        return []
    
    @property
    def parameter_names(self):
        return []
    
    def get_gradients(self, dLdY, fprop_context):
        return []
    

class AffineLayer(Layer):
    def __init__(self, num_in, num_out, weight_init=None, bias_init=None, **kwargs):
        super(AffineLayer, self).__init__(**kwargs)
        if weight_init is None:
            #
            # TODO propose a default initialization scheme.
            # Type a sentence explaining why, and if you use a reference, 
            # cite it here
            #
            weight_init = Uniform(0, 2/(num_in**0.5))
        if bias_init is None:
            bias_init = Constant(0.0)
        
        self.W = weight_init.generate(self.rng, (num_out, num_in))
        self.b = bias_init.generate(self.rng, (num_out, 1))
    
    @property
    def parameters(self):
        return [self.W, self.b]
    
    @property
    def parameter_names(self):
        return ['W','b']
    
    def fprop(self, X):
        #Save X for later reusal
        fprop_context = dict(X=X)
        Y = np.dot(self.W, X) +  self.b
        return Y, fprop_context
    
    def bprop(self, dLdY, fprop_context):
        #
        # TODO: fill in gradient computation
        #
        dLdX = np.dot(self.W.T, dLdY)
        return dLdX
    
    def get_gradients(self, dLdY, fprop_context):
        X = fprop_context['X']
        dLdW = np.dot(dLdY, X.T)
        dLdb = dLdY.sum(1, keepdims=True)
        return [dLdW, dLdb]
    
class TanhLayer(Layer):
    def __init__(self, **kwargs):
        super(TanhLayer, self).__init__(**kwargs)
    
    def fprop(self, X):
        Y = np.tanh(X)
        fprop_context = dict(Y=Y)
        return Y, fprop_context
    
    def bprop(self, dLdY, fprop_context):
        Y = fprop_context['Y']
        #
        # Fill in proper gradient computation
        #
        return dLdY * (1 - (Y**2))

    
class ReLULayer(Layer):
    def __init__(self, **kwargs):
        super(ReLULayer, self).__init__(**kwargs)
    
    def fprop(self, X):
        Y = np.maximum(X, 0.0)
        fprop_context = dict(Y=Y)
        return Y, fprop_context
    
    def bprop(self, dLdY, fprop_context):
        Y = fprop_context['Y']
        return dLdY * (Y>0)

    
class SoftMaxLayer(Layer):
    def __init__(self, **kwargs):
        super(SoftMaxLayer, self).__init__(**kwargs)
    
    def compute_probabilities(self, X):
        O = X - X.max(axis=0, keepdims=True)
        O = np.exp(O)
        O /= O.sum(axis=0, keepdims=True)
        return O
    
    def fprop_cost(self, X, Y):
        NS = X.shape[1]
        O = self.compute_probabilities(X)
        Cost = -1.0/NS * np.log(O[Y.ravel(), range(NS)]).sum()
        return Cost, O, dict(O=O, X=X, Y=Y)
    
    def bprop_cost(self, fprop_context):
        X = fprop_context['X']
        Y = fprop_context['Y']
        O = fprop_context['O']
        NS = X.shape[1]
        dLdX = O.copy()
        dLdX[Y, range(NS)] -= 1.0
        dLdX /= NS
        return dLdX
    
class FeedForwardNet(object):
    def __init__(self, layers=None):
        if layers is None:
            layers = []
        self.layers = layers
    
    def add(self, layer):
        self.layers.append(layer)
    
    @property
    def parameters(self):
        params = []
        for layer in self.layers:
            params += layer.parameters
        return params
    
    @parameters.setter
    def parameters(self, values):
        for ownP, newP in zip(self.parameters, values):
            ownP[...] = newP
    
    @property
    def parameter_names(self):
        param_names = []
        for layer in self.layers:
            param_names += layer.parameter_names
        return param_names
    
    def fprop(self, X):
        for layer in self.layers[:-1]:
            X, fp_context = layer.fprop(X)
        return self.layers[-1].compute_probabilities(X)
    
    def get_cost_and_gradient(self, X, Y):
        fp_contexts = []
        for layer in self.layers[:-1]:
            X, fp_context = layer.fprop(X)
            fp_contexts.append(fp_context)
        
        L, O, fp_context = self.layers[-1].fprop_cost(X, Y)
        dLdX = self.layers[-1].bprop_cost(fp_context)
        
        dLdP = [] #gradient with respect to parameters
        for i in xrange(len(self.layers)-1):
            layer = self.layers[len(self.layers)-2-i]
            fp_context = fp_contexts[len(self.layers)-2-i]
            dLdP = layer.get_gradients(dLdX, fp_context) + dLdP
            dLdX = layer.bprop(dLdX, fp_context)
        return L, O, dLdP

# %%
#training algorithms. They change the network!
def GD(net, X, Y, alpha=1e-4, max_iters=1000000, tolerance=1e-6):
    """
    Simple batch gradient descent
    """
    old_L = np.inf
    for i in xrange(max_iters):
        L, O, gradients = net.get_cost_and_gradient(X, Y)
        if old_L < L:
            print "Iter: %d, loss increased!!" % (i,)
        if (old_L - L)<tolerance:
            print "Tolerance level reached exiting"
            break
        if i % 1000 == 0:
            err_rate = (O.argmax(0) != Y).mean()
            print "At iteration %d, loss %f, train error rate %f%%" % (i, L, err_rate*100)
        for P,G in zip(net.parameters, gradients):
            P -= alpha * G
        old_L = L

# %%
from sklearn import datasets
iris = datasets.load_iris()
IrisX = iris.data.T
IrisX = (IrisX - IrisX.mean(axis=1, keepdims=True)) / IrisX.std(axis=1, keepdims=True)
IrisY = iris.target.reshape(1,-1)

# %%
#
# Here we verify that the network can be trained on Irises.
# Most runs should result in 100% accurracy
#

net = FeedForwardNet([
        AffineLayer(4,10),
        TanhLayer(),
        AffineLayer(10,3),
        SoftMaxLayer()
        ])
GD(net, IrisX,IrisY, 1e-1, tolerance=1e-7, max_iters=50000)
# Out:
# At iteration 0, loss 1.206416, train error rate 94.666667%
# At iteration 1000, loss 0.052533, train error rate 2.000000%
# At iteration 2000, loss 0.043669, train error rate 1.333333%
# At iteration 3000, loss 0.041448, train error rate 1.333333%
# At iteration 4000, loss 0.040541, train error rate 1.333333%
# At iteration 5000, loss 0.040044, train error rate 1.333333%
# At iteration 6000, loss 0.039689, train error rate 1.333333%
# At iteration 7000, loss 0.039364, train error rate 1.333333%
# At iteration 8000, loss 0.039008, train error rate 1.333333%
# At iteration 9000, loss 0.038570, train error rate 1.333333%
# At iteration 10000, loss 0.037997, train error rate 1.333333%
# At iteration 11000, loss 0.037219, train error rate 1.333333%
# At iteration 12000, loss 0.036134, train error rate 1.333333%
# At iteration 13000, loss 0.034615, train error rate 1.333333%
# At iteration 14000, loss 0.032562, train error rate 1.333333%
# At iteration 15000, loss 0.029993, train error rate 1.333333%
# At iteration 16000, loss 0.027080, train error rate 1.333333%
# At iteration 17000, loss 0.024096, train error rate 0.666667%
# At iteration 18000, loss 0.021291, train error rate 0.666667%
# At iteration 19000, loss 0.018799, train error rate 0.666667%
# At iteration 20000, loss 0.016635, train error rate 0.666667%
# At iteration 21000, loss 0.014760, train error rate 0.666667%
# At iteration 22000, loss 0.013157, train error rate 0.000000%
# At iteration 23000, loss 0.011817, train error rate 0.000000%
# At iteration 24000, loss 0.010698, train error rate 0.000000%
# At iteration 25000, loss 0.009754, train error rate 0.000000%
# At iteration 26000, loss 0.008949, train error rate 0.000000%
# At iteration 27000, loss 0.008255, train error rate 0.000000%
# At iteration 28000, loss 0.007651, train error rate 0.000000%
# At iteration 29000, loss 0.007122, train error rate 0.000000%
# At iteration 30000, loss 0.006654, train error rate 0.000000%
# At iteration 31000, loss 0.006239, train error rate 0.000000%
# At iteration 32000, loss 0.005868, train error rate 0.000000%
# At iteration 33000, loss 0.005535, train error rate 0.000000%
# At iteration 34000, loss 0.005234, train error rate 0.000000%
# At iteration 35000, loss 0.004961, train error rate 0.000000%
# At iteration 36000, loss 0.004714, train error rate 0.000000%
# At iteration 37000, loss 0.004487, train error rate 0.000000%
# At iteration 38000, loss 0.004280, train error rate 0.000000%
# At iteration 39000, loss 0.004089, train error rate 0.000000%
# At iteration 40000, loss 0.003913, train error rate 0.000000%
# At iteration 41000, loss 0.003750, train error rate 0.000000%
# At iteration 42000, loss 0.003599, train error rate 0.000000%
# At iteration 43000, loss 0.003459, train error rate 0.000000%
# At iteration 44000, loss 0.003328, train error rate 0.000000%
# At iteration 45000, loss 0.003206, train error rate 0.000000%
# At iteration 46000, loss 0.003092, train error rate 0.000000%
# At iteration 47000, loss 0.002985, train error rate 0.000000%
# Tolerance level reached exiting

# %% [markdown]
# ## Reading data from Fuel
#
# The following cell prepares the data pipeline in fuel. please see SGD template for usage example

# %%
from fuel.datasets.mnist import MNIST
from fuel.transformers import ScaleAndShift, Cast, Flatten, Mapping
from fuel.streams import DataStream
from fuel.schemes import SequentialScheme, ShuffledScheme

MNIST.default_transformers = (
    (ScaleAndShift, [2.0 / 255.0, -1], {'which_sources': 'features'}),
    (Cast, [np.float32], {'which_sources': 'features'}), 
    (Flatten, [], {'which_sources': 'features'}),
    (Mapping, [lambda batch: (b.T for b in batch)], {}) )

mnist_train = MNIST(("train",), subset=slice(None,50000))
#this stream will shuffle the MNIST set and return us batches of 100 examples
mnist_train_stream = DataStream.default_stream(
    mnist_train,
    iteration_scheme=ShuffledScheme(mnist_train.num_examples, 100))
                                               
mnist_validation = MNIST(("train",), subset=slice(50000, None))

# We will use larger portions for testing and validation
# as these dont do a backward pass and reauire less RAM.
mnist_validation_stream = DataStream.default_stream(
    mnist_validation, iteration_scheme=SequentialScheme(mnist_validation.num_examples, 250))
mnist_test = MNIST(("test",))
mnist_test_stream = DataStream.default_stream(
    mnist_test, iteration_scheme=SequentialScheme(mnist_test.num_examples, 250))

# %%
print "The streams return batches containing %s" % (mnist_train_stream.sources,)

print "Each trainin batch consits of a tuple containing:"
for element in next(mnist_train_stream.get_epoch_iterator()):
    print " - an array of size %s containing %s" % (element.shape, element.dtype)
    
print "Validation/test batches consits of tuples containing:"
for element in next(mnist_test_stream.get_epoch_iterator()):
    print " - an array of size %s containing %s" % (element.shape, element.dtype)
# Out:
# The streams return batches containing (u'features', u'targets')
# Each trainin batch consits of a tuple containing:
#  - an array of size (784, 100) containing float32
#  - an array of size (1, 100) containing uint8
# Validation/test batches consits of tuples containing:
#  - an array of size (784, 250) containing float32
#  - an array of size (1, 250) containing uint8

# %% [markdown]
# # Problem 1 [4p]
#
# Implement the following additions to the SGD code below:
# 1. Momentum [2p]
# 2. Learning rate schedule [1p]
# 3. Weight decay [1p]. One way to implement it is to use the functions `net.params` and `net.param_names` to get all parameters whose names are "W" and not "b".

# %%
#
# Please note, the code blow is able to train a SoftMax regression model on mnist to poor results (ca 8%test error), 
# you must improve it
#

from copy import deepcopy

def compute_error_rate(net, stream):
    num_errs = 0.0
    num_examples = 0
    for X, Y in stream.get_epoch_iterator():
        O = net.fprop(X)
        num_errs += (O.argmax(0) != Y).sum()
        num_examples += X.shape[1]
    return num_errs/num_examples

def SGD(net, train_stream, validation_stream, test_stream):
    i=0
    e=0
    
    #initialize momentum variables
    #
    # TODO
    #
    # Hint: you need one valocity matrix for each parameter
    velocities = [np.zeros(P.shape) for P in net.parameters]
    
    best_valid_error_rate = np.inf
    best_params = deepcopy(net.parameters)
    best_params_epoch = 0
    
    train_erros = []
    train_loss = []
    validation_errors = []
    
    number_of_epochs = 3
    patience_expansion = 1.5
    alpha_start = 5e-2
    alpha = alpha_start
    
    try:
        while e<number_of_epochs: #This loop goes over epochs
            e += 1
            #First train on all data from this batch
            for X,Y in train_stream.get_epoch_iterator(): 
                i += 1
                L, O, gradients = net.get_cost_and_gradient(X, Y)
                err_rate = (O.argmax(0) != Y).mean()
                train_loss.append((i,L))
                train_erros.append((i,err_rate))
                if i % 100 == 0:
                    print "At minibatch %d, batch loss %f, batch error rate %f%%" % (i, L, err_rate*100)
                
                #if train_loss[i-1][1] > train_loss[i-2][1]:
                #    alpha *= 1.005
                #else:
                #    alpha *= 0.995
                
                for P, V, G, N in zip(net.parameters, velocities, gradients, net.parameter_names):
                    if N=='W':
                        #pass
                        #
                        # TODO: implement the weight decay addition to gradient
                        #
                        #G += TODO
                        G += 0.001 * P
                    
                    #
                    # TODO: set a learning rate
                    #
                    # Hint, use the iteration counter i
                    # alpha = TODO
                    
                    alpha = alpha_start * (0.995 ** e)
                    
                    #
                    # TODO: set the momentum constant 
                    # 
                    mi = 0.5
                    
                    # epsilon = TODO
                    
                    #
                    # TODO: implement velocity update in momentum
                    #
                    V = mi * V + alpha * G
                    
                    # V[...] = TODO
                    
                    #
                    # TODO: set a more sensible learning rule here,
                    # using your learning rate schedule and momentum
                    #
                    #!!!!! Need to modify the actual parameter here! 
                    P -= V
                    #P -= alpha * G
            # After an epoch compute validation error
            val_error_rate = compute_error_rate(net, validation_stream)
            if val_error_rate < best_valid_error_rate:
                number_of_epochs = np.maximum(number_of_epochs, e * patience_expansion+1)
                best_valid_error_rate = val_error_rate
                best_params = deepcopy(net.parameters)
                best_params_epoch = e
                validation_errors.append((i,val_error_rate))
            print "After epoch %d: valid_err_rate: %f%% currently going ot do %d epochs" %(
                e, val_error_rate, number_of_epochs)
            
    except KeyboardInterrupt:
        print "Setting network parameters from after epoch %d" %(best_params_epoch)
        net.parameters = best_params
        
        subplot(2,1,1)
        train_loss = np.array(train_loss)
        semilogy(train_loss[:,0], train_loss[:,1], label='batch train loss')
        legend()
        
        subplot(2,1,2)
        train_erros = np.array(train_erros)
        plot(train_erros[:,0], train_erros[:,1], label='batch train error rate')
        validation_errors = np.array(validation_errors)
        plot(validation_errors[:,0], validation_errors[:,1], label='validation error rate', color='r')
        ylim(0,0.2)
        legend()

# %% [markdown]
# # Problem 2 [5p]
#
# Tune the following network to reach below 1.9% error rate on
# the validation set. This should result in a test error below 2%. To
# tune the network you will need to:
# 1. choose the number of layers (more than 1, less than 5),
# 2. choose the number of neurons in each layer (more than 100,
#     less than 5000),
# 3. pick proper weight initialization,
# 4. pick proper learning rate schedule (need to decay over time,
#     good range to check on MNIST is about 1e-2 ... 1e-1 at the beginning and
#     half of that after 10000 batches),
# 5. pick a momentum constant (probably a constant one will be OK).

# %%
#
# TODO: pick a network architecture here. The one below is just 
# softmax regression
#

net = FeedForwardNet([
        AffineLayer(784,300),
        ReLULayer(),
        AffineLayer(300,300),
        ReLULayer(),
        AffineLayer(300,300),
        ReLULayer(),
        AffineLayer(300,10),
        SoftMaxLayer()
        ])
SGD(net, mnist_train_stream, mnist_validation_stream, mnist_test_stream)

print "Test error rate: %f" % (compute_error_rate(net, mnist_test_stream), )
# Out:
# At minibatch 100, batch loss 1.101761, batch error rate 38.000000%
# At minibatch 200, batch loss 0.712377, batch error rate 23.000000%
# At minibatch 300, batch loss 0.527642, batch error rate 21.000000%
# At minibatch 400, batch loss 0.271434, batch error rate 8.000000%
# At minibatch 500, batch loss 0.366216, batch error rate 12.000000%
# After epoch 1: valid_err_rate: 0.090300% currently going ot do 3 epochs
# At minibatch 600, batch loss 0.448387, batch error rate 12.000000%
# At minibatch 700, batch loss 0.211136, batch error rate 7.000000%
# At minibatch 800, batch loss 0.284821, batch error rate 9.000000%
# At minibatch 900, batch loss 0.209409, batch error rate 5.000000%
# At minibatch 1000, batch loss 0.190470, batch error rate 6.000000%
# After epoch 2: valid_err_rate: 0.068300% currently going ot do 4 epochs
# At minibatch 1100, batch loss 0.324135, batch error rate 15.000000%
# At minibatch 1200, batch loss 0.158434, batch error rate 6.000000%
# At minibatch 1300, batch loss 0.276336, batch error rate 7.000000%
# At minibatch 1400, batch loss 0.222059, batch error rate 6.000000%
# At minibatch 1500, batch loss 0.151932, batch error rate 3.000000%
# After epoch 3: valid_err_rate: 0.050500% currently going ot do 5 epochs
# At minibatch 1600, batch loss 0.224409, batch error rate 7.000000%
# At minibatch 1700, batch loss 0.369192, batch error rate 11.000000%
# At minibatch 1800, batch loss 0.206902, batch error rate 8.000000%
# At minibatch 1900, batch loss 0.067938, batch error rate 1.000000%
# At minibatch 2000, batch loss 0.177783, batch error rate 5.000000%
# After epoch 4: valid_err_rate: 0.047200% currently going ot do 7 epochs
# At minibatch 2100, batch loss 0.103280, batch error rate 3.000000%
# At minibatch 2200, batch loss 0.299428, batch error rate 11.000000%
# At minibatch 2300, batch loss 0.097542, batch error rate 3.000000%
# At minibatch 2400, batch loss 0.197908, batch error rate 9.000000%
# At minibatch 2500, batch loss 0.108901, batch error rate 3.000000%
# After epoch 5: valid_err_rate: 0.037100% currently going ot do 8 epochs
# At minibatch 2600, batch loss 0.064390, batch error rate 1.000000%
# At minibatch 2700, batch loss 0.124024, batch error rate 3.000000%
# At minibatch 2800, batch loss 0.118287, batch error rate 4.000000%
# At minibatch 2900, batch loss 0.120862, batch error rate 4.000000%
# At minibatch 3000, batch loss 0.160454, batch error rate 7.000000%
# After epoch 6: valid_err_rate: 0.029400% currently going ot do 10 epochs
# At minibatch 3100, batch loss 0.168730, batch error rate 5.000000%
# At minibatch 3200, batch loss 0.093695, batch error rate 3.000000%
# At minibatch 3300, batch loss 0.078419, batch error rate 2.000000%
# At minibatch 3400, batch loss 0.085225, batch error rate 3.000000%
# At minibatch 3500, batch loss 0.201691, batch error rate 7.000000%
# After epoch 7: valid_err_rate: 0.037600% currently going ot do 10 epochs
# At minibatch 3600, batch loss 0.067597, batch error rate 2.000000%
# At minibatch 3700, batch loss 0.071918, batch error rate 3.000000%
# At minibatch 3800, batch loss 0.066278, batch error rate 2.000000%
# At minibatch 3900, batch loss 0.068832, batch error rate 4.000000%
# At minibatch 4000, batch loss 0.082329, batch error rate 2.000000%
# After epoch 8: valid_err_rate: 0.029100% currently going ot do 13 epochs
# At minibatch 4100, batch loss 0.072721, batch error rate 3.000000%
# At minibatch 4200, batch loss 0.019431, batch error rate 0.000000%
# At minibatch 4300, batch loss 0.043845, batch error rate 2.000000%
# At minibatch 4400, batch loss 0.069779, batch error rate 2.000000%
# At minibatch 4500, batch loss 0.013202, batch error rate 0.000000%
# After epoch 9: valid_err_rate: 0.027600% currently going ot do 14 epochs
# At minibatch 4600, batch loss 0.082324, batch error rate 4.000000%
# At minibatch 4700, batch loss 0.029089, batch error rate 0.000000%
# At minibatch 4800, batch loss 0.067932, batch error rate 4.000000%
# At minibatch 4900, batch loss 0.050148, batch error rate 1.000000%
# At minibatch 5000, batch loss 0.017104, batch error rate 0.000000%
# After epoch 10: valid_err_rate: 0.025600% currently going ot do 16 epochs
# At minibatch 5100, batch loss 0.057994, batch error rate 1.000000%
# At minibatch 5200, batch loss 0.052834, batch error rate 1.000000%
# At minibatch 5300, batch loss 0.073544, batch error rate 3.000000%
# At minibatch 5400, batch loss 0.133432, batch error rate 3.000000%
# At minibatch 5500, batch loss 0.068937, batch error rate 2.000000%
# After epoch 11: valid_err_rate: 0.022500% currently going ot do 17 epochs
# At minibatch 5600, batch loss 0.032415, batch error rate 2.000000%
# At minibatch 5700, batch loss 0.039168, batch error rate 2.000000%
# At minibatch 5800, batch loss 0.038707, batch error rate 1.000000%
# At minibatch 5900, batch loss 0.053998, batch error rate 3.000000%
# At minibatch 6000, batch loss 0.025850, batch error rate 0.000000%
# After epoch 12: valid_err_rate: 0.021800% currently going ot do 19 epochs
# At minibatch 6100, batch loss 0.022800, batch error rate 1.000000%
# At minibatch 6200, batch loss 0.021380, batch error rate 0.000000%
# At minibatch 6300, batch loss 0.078343, batch error rate 2.000000%
# At minibatch 6400, batch loss 0.068130, batch error rate 2.000000%
# At minibatch 6500, batch loss 0.125545, batch error rate 3.000000%
# After epoch 13: valid_err_rate: 0.031600% currently going ot do 19 epochs
# At minibatch 6600, batch loss 0.038301, batch error rate 1.000000%
# At minibatch 6700, batch loss 0.010519, batch error rate 0.000000%
# At minibatch 6800, batch loss 0.054664, batch error rate 2.000000%
# At minibatch 6900, batch loss 0.055190, batch error rate 2.000000%
# At minibatch 7000, batch loss 0.279551, batch error rate 11.000000%
# After epoch 14: valid_err_rate: 0.350900% currently going ot do 19 epochs
# At minibatch 7100, batch loss 0.079633, batch error rate 1.000000%
# At minibatch 7200, batch loss 0.049938, batch error rate 2.000000%
# At minibatch 7300, batch loss 0.048955, batch error rate 2.000000%
# At minibatch 7400, batch loss 0.098092, batch error rate 3.000000%
# At minibatch 7500, batch loss 0.043387, batch error rate 2.000000%
# After epoch 15: valid_err_rate: 0.022800% currently going ot do 19 epochs
# At minibatch 7600, batch loss 0.048858, batch error rate 1.000000%
# At minibatch 7700, batch loss 0.107444, batch error rate 2.000000%
# At minibatch 7800, batch loss 0.016587, batch error rate 0.000000%
# At minibatch 7900, batch loss 0.035995, batch error rate 2.000000%
# At minibatch 8000, batch loss 0.020140, batch error rate 1.000000%
# After epoch 16: valid_err_rate: 0.024500% currently going ot do 19 epochs
# At minibatch 8100, batch loss 0.010281, batch error rate 0.000000%
# At minibatch 8200, batch loss 0.086102, batch error rate 4.000000%
# At minibatch 8300, batch loss 0.014164, batch error rate 0.000000%
# At minibatch 8400, batch loss 0.076379, batch error rate 4.000000%
# At minibatch 8500, batch loss 0.020265, batch error rate 1.000000%
# After epoch 17: valid_err_rate: 0.021600% currently going ot do 26 epochs
# At minibatch 8600, batch loss 0.007698, batch error rate 0.000000%
# At minibatch 8700, batch loss 0.037175, batch error rate 1.000000%
# At minibatch 8800, batch loss 0.043606, batch error rate 2.000000%
# At minibatch 8900, batch loss 0.033823, batch error rate 1.000000%
# At minibatch 9000, batch loss 0.032314, batch error rate 1.000000%
# After epoch 18: valid_err_rate: 0.024000% currently going ot do 26 epochs
# At minibatch 9100, batch loss 0.015137, batch error rate 0.000000%
# At minibatch 9200, batch loss 0.027092, batch error rate 1.000000%
# At minibatch 9300, batch loss 0.033346, batch error rate 2.000000%
# At minibatch 9400, batch loss 0.056168, batch error rate 1.000000%
# At minibatch 9500, batch loss 0.034107, batch error rate 1.000000%
# After epoch 19: valid_err_rate: 0.023200% currently going ot do 26 epochs
# At minibatch 9600, batch loss 0.009905, batch error rate 0.000000%
# At minibatch 9700, batch loss 0.069597, batch error rate 1.000000%
# At minibatch 9800, batch loss 0.034754, batch error rate 1.000000%
# At minibatch 9900, batch loss 0.009165, batch error rate 1.000000%
# At minibatch 10000, batch loss 0.040808, batch error rate 2.000000%
# After epoch 20: valid_err_rate: 0.023100% currently going ot do 26 epochs
# At minibatch 10100, batch loss 0.004997, batch error rate 0.000000%
# At minibatch 10200, batch loss 0.016107, batch error rate 0.000000%
# At minibatch 10300, batch loss 0.036300, batch error rate 1.000000%
# At minibatch 10400, batch loss 0.020486, batch error rate 1.000000%
# At minibatch 10500, batch loss 0.013252, batch error rate 1.000000%
# After epoch 21: valid_err_rate: 0.018900% currently going ot do 32 epochs
# At minibatch 10600, batch loss 0.056158, batch error rate 3.000000%
# At minibatch 10700, batch loss 0.054890, batch error rate 2.000000%
# At minibatch 10800, batch loss 0.010013, batch error rate 1.000000%
# At minibatch 10900, batch loss 0.006857, batch error rate 0.000000%
# At minibatch 11000, batch loss 0.035177, batch error rate 1.000000%
# After epoch 22: valid_err_rate: 0.022700% currently going ot do 32 epochs
# At minibatch 11100, batch loss 0.004681, batch error rate 0.000000%
# At minibatch 11200, batch loss 0.018800, batch error rate 1.000000%
# At minibatch 11300, batch loss 0.009914, batch error rate 0.000000%
# At minibatch 11400, batch loss 0.001715, batch error rate 0.000000%
# At minibatch 11500, batch loss 0.004829, batch error rate 0.000000%
# After epoch 23: valid_err_rate: 0.020600% currently going ot do 32 epochs
# At minibatch 11600, batch loss 0.005334, batch error rate 0.000000%
# At minibatch 11700, batch loss 0.029410, batch error rate 1.000000%
# At minibatch 11800, batch loss 0.004873, batch error rate 0.000000%
# At minibatch 11900, batch loss 0.003909, batch error rate 0.000000%
# At minibatch 12000, batch loss 0.012358, batch error rate 0.000000%
# After epoch 24: valid_err_rate: 0.020800% currently going ot do 32 epochs
# At minibatch 12100, batch loss 0.004569, batch error rate 0.000000%
# At minibatch 12200, batch loss 0.014650, batch error rate 1.000000%
# At minibatch 12300, batch loss 0.022698, batch error rate 1.000000%
# At minibatch 12400, batch loss 0.002943, batch error rate 0.000000%
# At minibatch 12500, batch loss 0.004119, batch error rate 0.000000%
# After epoch 25: valid_err_rate: 0.017800% currently going ot do 38 epochs
# At minibatch 12600, batch loss 0.005246, batch error rate 0.000000%
# At minibatch 12700, batch loss 0.002094, batch error rate 0.000000%
# At minibatch 12800, batch loss 0.001442, batch error rate 0.000000%
# At minibatch 12900, batch loss 0.005419, batch error rate 0.000000%
# At minibatch 13000, batch loss 0.014241, batch error rate 1.000000%
# After epoch 26: valid_err_rate: 0.018600% currently going ot do 38 epochs
# At minibatch 13100, batch loss 0.001759, batch error rate 0.000000%
# At minibatch 13200, batch loss 0.004260, batch error rate 0.000000%
# At minibatch 13300, batch loss 0.005138, batch error rate 0.000000%
# At minibatch 13400, batch loss 0.006546, batch error rate 0.000000%
# At minibatch 13500, batch loss 0.004999, batch error rate 0.000000%
# After epoch 27: valid_err_rate: 0.020600% currently going ot do 38 epochs
# At minibatch 13600, batch loss 0.007472, batch error rate 0.000000%
# At minibatch 13700, batch loss 0.001827, batch error rate 0.000000%
# At minibatch 13800, batch loss 0.001737, batch error rate 0.000000%
# At minibatch 13900, batch loss 0.012140, batch error rate 0.000000%
# At minibatch 14000, batch loss 0.011287, batch error rate 0.000000%
# After epoch 28: valid_err_rate: 0.018300% currently going ot do 38 epochs
# At minibatch 14100, batch loss 0.021247, batch error rate 1.000000%
# At minibatch 14200, batch loss 0.002490, batch error rate 0.000000%
# At minibatch 14300, batch loss 0.004270, batch error rate 0.000000%
# At minibatch 14400, batch loss 0.003453, batch error rate 0.000000%
# At minibatch 14500, batch loss 0.000550, batch error rate 0.000000%
# After epoch 29: valid_err_rate: 0.018200% currently going ot do 38 epochs
# At minibatch 14600, batch loss 0.005014, batch error rate 0.000000%
# At minibatch 14700, batch loss 0.012452, batch error rate 1.000000%
# At minibatch 14800, batch loss 0.001329, batch error rate 0.000000%
# At minibatch 14900, batch loss 0.004500, batch error rate 0.000000%
# At minibatch 15000, batch loss 0.001858, batch error rate 0.000000%
# After epoch 30: valid_err_rate: 0.017400% currently going ot do 46 epochs
# At minibatch 15100, batch loss 0.000527, batch error rate 0.000000%
# At minibatch 15200, batch loss 0.002890, batch error rate 0.000000%
# At minibatch 15300, batch loss 0.006649, batch error rate 0.000000%
# At minibatch 15400, batch loss 0.008741, batch error rate 0.000000%
# At minibatch 15500, batch loss 0.001912, batch error rate 0.000000%
# After epoch 31: valid_err_rate: 0.017300% currently going ot do 47 epochs
# At minibatch 15600, batch loss 0.006056, batch error rate 0.000000%
# At minibatch 15700, batch loss 0.003575, batch error rate 0.000000%
# At minibatch 15800, batch loss 0.002212, batch error rate 0.000000%
# At minibatch 15900, batch loss 0.001428, batch error rate 0.000000%
# At minibatch 16000, batch loss 0.002436, batch error rate 0.000000%
# After epoch 32: valid_err_rate: 0.017300% currently going ot do 47 epochs
# At minibatch 16100, batch loss 0.003284, batch error rate 0.000000%
# At minibatch 16200, batch loss 0.002831, batch error rate 0.000000%
# At minibatch 16300, batch loss 0.004911, batch error rate 0.000000%
# At minibatch 16400, batch loss 0.000771, batch error rate 0.000000%
# At minibatch 16500, batch loss 0.003154, batch error rate 0.000000%
# After epoch 33: valid_err_rate: 0.017900% currently going ot do 47 epochs
# At minibatch 16600, batch loss 0.003050, batch error rate 0.000000%
# At minibatch 16700, batch loss 0.004633, batch error rate 0.000000%
# At minibatch 16800, batch loss 0.000718, batch error rate 0.000000%
# At minibatch 16900, batch loss 0.006578, batch error rate 0.000000%
# At minibatch 17000, batch loss 0.008764, batch error rate 0.000000%
# After epoch 34: valid_err_rate: 0.018500% currently going ot do 47 epochs
# At minibatch 17100, batch loss 0.002467, batch error rate 0.000000%
# At minibatch 17200, batch loss 0.002765, batch error rate 0.000000%
# At minibatch 17300, batch loss 0.001770, batch error rate 0.000000%
# At minibatch 17400, batch loss 0.005678, batch error rate 0.000000%
# At minibatch 17500, batch loss 0.005065, batch error rate 0.000000%
# After epoch 35: valid_err_rate: 0.017600% currently going ot do 47 epochs
# At minibatch 17600, batch loss 0.004607, batch error rate 0.000000%
# At minibatch 17700, batch loss 0.002638, batch error rate 0.000000%
# At minibatch 17800, batch loss 0.001236, batch error rate 0.000000%
# At minibatch 17900, batch loss 0.006313, batch error rate 0.000000%
# At minibatch 18000, batch loss 0.000633, batch error rate 0.000000%
# After epoch 36: valid_err_rate: 0.017600% currently going ot do 47 epochs
# At minibatch 18100, batch loss 0.002385, batch error rate 0.000000%
# At minibatch 18200, batch loss 0.001590, batch error rate 0.000000%
# At minibatch 18300, batch loss 0.004619, batch error rate 0.000000%
# At minibatch 18400, batch loss 0.002672, batch error rate 0.000000%
# At minibatch 18500, batch loss 0.001892, batch error rate 0.000000%
# After epoch 37: valid_err_rate: 0.017000% currently going ot do 56 epochs
# At minibatch 18600, batch loss 0.000834, batch error rate 0.000000%
# At minibatch 18700, batch loss 0.000988, batch error rate 0.000000%
# At minibatch 18800, batch loss 0.002113, batch error rate 0.000000%
# At minibatch 18900, batch loss 0.002933, batch error rate 0.000000%
# At minibatch 19000, batch loss 0.000813, batch error rate 0.000000%
# After epoch 38: valid_err_rate: 0.017100% currently going ot do 56 epochs
# At minibatch 19100, batch loss 0.001554, batch error rate 0.000000%
# At minibatch 19200, batch loss 0.000513, batch error rate 0.000000%
# At minibatch 19300, batch loss 0.002081, batch error rate 0.000000%
# At minibatch 19400, batch loss 0.007990, batch error rate 0.000000%
# At minibatch 19500, batch loss 0.000461, batch error rate 0.000000%
# After epoch 39: valid_err_rate: 0.017000% currently going ot do 56 epochs
# At minibatch 19600, batch loss 0.000671, batch error rate 0.000000%
# At minibatch 19700, batch loss 0.003949, batch error rate 0.000000%
# At minibatch 19800, batch loss 0.012479, batch error rate 1.000000%
# At minibatch 19900, batch loss 0.002219, batch error rate 0.000000%
# At minibatch 20000, batch loss 0.000719, batch error rate 0.000000%
# After epoch 40: valid_err_rate: 0.016400% currently going ot do 61 epochs
# At minibatch 20100, batch loss 0.001516, batch error rate 0.000000%
# At minibatch 20200, batch loss 0.000558, batch error rate 0.000000%
# At minibatch 20300, batch loss 0.000265, batch error rate 0.000000%
# At minibatch 20400, batch loss 0.000758, batch error rate 0.000000%
# At minibatch 20500, batch loss 0.000886, batch error rate 0.000000%
# After epoch 41: valid_err_rate: 0.017600% currently going ot do 61 epochs
# At minibatch 20600, batch loss 0.002026, batch error rate 0.000000%
# At minibatch 20700, batch loss 0.001149, batch error rate 0.000000%
# At minibatch 20800, batch loss 0.000571, batch error rate 0.000000%
# At minibatch 20900, batch loss 0.000554, batch error rate 0.000000%
# At minibatch 21000, batch loss 0.000435, batch error rate 0.000000%
# After epoch 42: valid_err_rate: 0.016700% currently going ot do 61 epochs
# At minibatch 21100, batch loss 0.001106, batch error rate 0.000000%
# At minibatch 21200, batch loss 0.001475, batch error rate 0.000000%
# At minibatch 21300, batch loss 0.000907, batch error rate 0.000000%
# At minibatch 21400, batch loss 0.000370, batch error rate 0.000000%
# At minibatch 21500, batch loss 0.000581, batch error rate 0.000000%
# After epoch 43: valid_err_rate: 0.017600% currently going ot do 61 epochs
# At minibatch 21600, batch loss 0.001848, batch error rate 0.000000%
# At minibatch 21700, batch loss 0.000590, batch error rate 0.000000%
# At minibatch 21800, batch loss 0.000447, batch error rate 0.000000%
# At minibatch 21900, batch loss 0.000339, batch error rate 0.000000%
# At minibatch 22000, batch loss 0.000714, batch error rate 0.000000%
# After epoch 44: valid_err_rate: 0.017200% currently going ot do 61 epochs
# At minibatch 22100, batch loss 0.000950, batch error rate 0.000000%
# At minibatch 22200, batch loss 0.005102, batch error rate 0.000000%
# At minibatch 22300, batch loss 0.000275, batch error rate 0.000000%
# At minibatch 22400, batch loss 0.000919, batch error rate 0.000000%
# At minibatch 22500, batch loss 0.001768, batch error rate 0.000000%
# After epoch 45: valid_err_rate: 0.016700% currently going ot do 61 epochs
# At minibatch 22600, batch loss 0.000532, batch error rate 0.000000%
# At minibatch 22700, batch loss 0.000783, batch error rate 0.000000%
# At minibatch 22800, batch loss 0.000795, batch error rate 0.000000%
# At minibatch 22900, batch loss 0.001326, batch error rate 0.000000%
# At minibatch 23000, batch loss 0.001010, batch error rate 0.000000%
# After epoch 46: valid_err_rate: 0.016700% currently going ot do 61 epochs
# At minibatch 23100, batch loss 0.000648, batch error rate 0.000000%
# At minibatch 23200, batch loss 0.000433, batch error rate 0.000000%
# At minibatch 23300, batch loss 0.000538, batch error rate 0.000000%
# At minibatch 23400, batch loss 0.000493, batch error rate 0.000000%
# At minibatch 23500, batch loss 0.001528, batch error rate 0.000000%
# After epoch 47: valid_err_rate: 0.017200% currently going ot do 61 epochs
# At minibatch 23600, batch loss 0.001657, batch error rate 0.000000%
# At minibatch 23700, batch loss 0.000647, batch error rate 0.000000%
# At minibatch 23800, batch loss 0.001271, batch error rate 0.000000%
# At minibatch 23900, batch loss 0.001312, batch error rate 0.000000%
# At minibatch 24000, batch loss 0.007193, batch error rate 0.000000%
# After epoch 48: valid_err_rate: 0.017400% currently going ot do 61 epochs
# At minibatch 24100, batch loss 0.000490, batch error rate 0.000000%
# At minibatch 24200, batch loss 0.000333, batch error rate 0.000000%
# At minibatch 24300, batch loss 0.000573, batch error rate 0.000000%
# At minibatch 24400, batch loss 0.000634, batch error rate 0.000000%
# At minibatch 24500, batch loss 0.000454, batch error rate 0.000000%
# After epoch 49: valid_err_rate: 0.017300% currently going ot do 61 epochs
# At minibatch 24600, batch loss 0.001631, batch error rate 0.000000%
# At minibatch 24700, batch loss 0.000781, batch error rate 0.000000%
# At minibatch 24800, batch loss 0.000424, batch error rate 0.000000%
# At minibatch 24900, batch loss 0.001159, batch error rate 0.000000%
# At minibatch 25000, batch loss 0.000302, batch error rate 0.000000%
# After epoch 50: valid_err_rate: 0.017300% currently going ot do 61 epochs
# At minibatch 25100, batch loss 0.000675, batch error rate 0.000000%
# At minibatch 25200, batch loss 0.002901, batch error rate 0.000000%
# At minibatch 25300, batch loss 0.001121, batch error rate 0.000000%
# At minibatch 25400, batch loss 0.000420, batch error rate 0.000000%
# At minibatch 25500, batch loss 0.001726, batch error rate 0.000000%
# After epoch 51: valid_err_rate: 0.016700% currently going ot do 61 epochs
# At minibatch 25600, batch loss 0.000383, batch error rate 0.000000%
# At minibatch 25700, batch loss 0.000265, batch error rate 0.000000%
# At minibatch 25800, batch loss 0.000924, batch error rate 0.000000%
# At minibatch 25900, batch loss 0.000951, batch error rate 0.000000%
# At minibatch 26000, batch loss 0.002075, batch error rate 0.000000%
# After epoch 52: valid_err_rate: 0.016800% currently going ot do 61 epochs
# At minibatch 26100, batch loss 0.000598, batch error rate 0.000000%
# At minibatch 26200, batch loss 0.000183, batch error rate 0.000000%
# At minibatch 26300, batch loss 0.000410, batch error rate 0.000000%
# At minibatch 26400, batch loss 0.000402, batch error rate 0.000000%
# At minibatch 26500, batch loss 0.000390, batch error rate 0.000000%
# After epoch 53: valid_err_rate: 0.016500% currently going ot do 61 epochs
# At minibatch 26600, batch loss 0.000173, batch error rate 0.000000%
# At minibatch 26700, batch loss 0.000960, batch error rate 0.000000%
# At minibatch 26800, batch loss 0.000925, batch error rate 0.000000%
# At minibatch 26900, batch loss 0.001284, batch error rate 0.000000%
# At minibatch 27000, batch loss 0.001106, batch error rate 0.000000%
# After epoch 54: valid_err_rate: 0.016800% currently going ot do 61 epochs
# At minibatch 27100, batch loss 0.000897, batch error rate 0.000000%
# At minibatch 27200, batch loss 0.000953, batch error rate 0.000000%
# At minibatch 27300, batch loss 0.000536, batch error rate 0.000000%
# At minibatch 27400, batch loss 0.001192, batch error rate 0.000000%
# At minibatch 27500, batch loss 0.000803, batch error rate 0.000000%
# After epoch 55: valid_err_rate: 0.016900% currently going ot do 61 epochs
# At minibatch 27600, batch loss 0.000680, batch error rate 0.000000%
# At minibatch 27700, batch loss 0.000255, batch error rate 0.000000%
# At minibatch 27800, batch loss 0.000349, batch error rate 0.000000%
# At minibatch 27900, batch loss 0.000461, batch error rate 0.000000%
# At minibatch 28000, batch loss 0.000497, batch error rate 0.000000%
# After epoch 56: valid_err_rate: 0.017000% currently going ot do 61 epochs
# At minibatch 28100, batch loss 0.000277, batch error rate 0.000000%
# At minibatch 28200, batch loss 0.000206, batch error rate 0.000000%
# At minibatch 28300, batch loss 0.000353, batch error rate 0.000000%
# At minibatch 28400, batch loss 0.000350, batch error rate 0.000000%
# At minibatch 28500, batch loss 0.000189, batch error rate 0.000000%
# After epoch 57: valid_err_rate: 0.017000% currently going ot do 61 epochs
# At minibatch 28600, batch loss 0.000501, batch error rate 0.000000%
# At minibatch 28700, batch loss 0.000614, batch error rate 0.000000%
# At minibatch 28800, batch loss 0.000696, batch error rate 0.000000%
# At minibatch 28900, batch loss 0.000793, batch error rate 0.000000%
# At minibatch 29000, batch loss 0.000840, batch error rate 0.000000%
# After epoch 58: valid_err_rate: 0.017000% currently going ot do 61 epochs
# At minibatch 29100, batch loss 0.000195, batch error rate 0.000000%
# At minibatch 29200, batch loss 0.001569, batch error rate 0.000000%
# At minibatch 29300, batch loss 0.000499, batch error rate 0.000000%
# At minibatch 29400, batch loss 0.001806, batch error rate 0.000000%
# At minibatch 29500, batch loss 0.000436, batch error rate 0.000000%
# After epoch 59: valid_err_rate: 0.017000% currently going ot do 61 epochs
# At minibatch 29600, batch loss 0.000739, batch error rate 0.000000%
# At minibatch 29700, batch loss 0.000808, batch error rate 0.000000%
# At minibatch 29800, batch loss 0.000724, batch error rate 0.000000%
# At minibatch 29900, batch loss 0.000062, batch error rate 0.000000%
# At minibatch 30000, batch loss 0.000640, batch error rate 0.000000%
# After epoch 60: valid_err_rate: 0.016800% currently going ot do 61 epochs
# At minibatch 30100, batch loss 0.000675, batch error rate 0.000000%
# At minibatch 30200, batch loss 0.000041, batch error rate 0.000000%
# At minibatch 30300, batch loss 0.000141, batch error rate 0.000000%
# At minibatch 30400, batch loss 0.000203, batch error rate 0.000000%
# At minibatch 30500, batch loss 0.000232, batch error rate 0.000000%
# After epoch 61: valid_err_rate: 0.017400% currently going ot do 61 epochs
# Test error rate: 0.018500

# %%
compute_error_rate(net, mnist_test_stream)
# Out:
# 0.0185

# %%
#
# TODO: pick a network architecture here. The one below is just 
# softmax regression
#

net = FeedForwardNet([
        AffineLayer(784,300),
        ReLULayer(),
        AffineLayer(300,300),
        ReLULayer(),
        AffineLayer(300,300),
        ReLULayer(),
        AffineLayer(300,10),
        SoftMaxLayer()
        ])
SGD(net, mnist_train_stream, mnist_validation_stream, mnist_test_stream)

print "Test error rate: %f" % (compute_error_rate(net, mnist_test_stream), )
# Out:
# At minibatch 100, batch loss 1.215925, batch error rate 36.000000%
# At minibatch 200, batch loss 0.649979, batch error rate 24.000000%
# At minibatch 300, batch loss 0.423382, batch error rate 12.000000%
# At minibatch 400, batch loss 0.334794, batch error rate 16.000000%
# At minibatch 500, batch loss 0.325319, batch error rate 10.000000%
# After epoch 1: valid_err_rate: 0.091000% currently going ot do 3 epochs
# At minibatch 600, batch loss 0.222406, batch error rate 5.000000%
# At minibatch 700, batch loss 0.230360, batch error rate 10.000000%
# At minibatch 800, batch loss 0.259235, batch error rate 9.000000%
# At minibatch 900, batch loss 0.172913, batch error rate 4.000000%
# At minibatch 1000, batch loss 0.236824, batch error rate 10.000000%
# After epoch 2: valid_err_rate: 0.075300% currently going ot do 4 epochs
# At minibatch 1100, batch loss 0.220825, batch error rate 7.000000%
# At minibatch 1200, batch loss 0.126325, batch error rate 3.000000%
# At minibatch 1300, batch loss 0.246845, batch error rate 10.000000%
# At minibatch 1400, batch loss 0.139642, batch error rate 6.000000%
# At minibatch 1500, batch loss 0.209171, batch error rate 6.000000%
# After epoch 3: valid_err_rate: 0.056400% currently going ot do 5 epochs
# At minibatch 1600, batch loss 0.155050, batch error rate 4.000000%
# At minibatch 1700, batch loss 0.286805, batch error rate 6.000000%
# At minibatch 1800, batch loss 0.165279, batch error rate 4.000000%
# At minibatch 1900, batch loss 0.176780, batch error rate 4.000000%
# At minibatch 2000, batch loss 0.168769, batch error rate 6.000000%
# After epoch 4: valid_err_rate: 0.044600% currently going ot do 7 epochs
# At minibatch 2100, batch loss 0.239402, batch error rate 6.000000%
# At minibatch 2200, batch loss 0.089152, batch error rate 3.000000%
# At minibatch 2300, batch loss 0.179411, batch error rate 5.000000%
# At minibatch 2400, batch loss 0.089046, batch error rate 3.000000%
# At minibatch 2500, batch loss 0.177546, batch error rate 6.000000%
# After epoch 5: valid_err_rate: 0.036200% currently going ot do 8 epochs
# At minibatch 2600, batch loss 0.116615, batch error rate 3.000000%
# At minibatch 2700, batch loss 0.291442, batch error rate 7.000000%
# At minibatch 2800, batch loss 0.153458, batch error rate 6.000000%
# At minibatch 2900, batch loss 0.099483, batch error rate 3.000000%
# At minibatch 3000, batch loss 0.149549, batch error rate 4.000000%
# After epoch 6: valid_err_rate: 0.032800% currently going ot do 10 epochs
# At minibatch 3100, batch loss 0.058146, batch error rate 1.000000%
# At minibatch 3200, batch loss 0.140080, batch error rate 3.000000%
# At minibatch 3300, batch loss 0.172367, batch error rate 3.000000%
# At minibatch 3400, batch loss 0.092802, batch error rate 3.000000%
# At minibatch 3500, batch loss 0.151152, batch error rate 4.000000%
# After epoch 7: valid_err_rate: 0.033900% currently going ot do 10 epochs
# At minibatch 3600, batch loss 0.036937, batch error rate 1.000000%
# At minibatch 3700, batch loss 0.088869, batch error rate 3.000000%
# At minibatch 3800, batch loss 0.056080, batch error rate 2.000000%
# At minibatch 3900, batch loss 0.096588, batch error rate 1.000000%
# At minibatch 4000, batch loss 0.075231, batch error rate 4.000000%
# After epoch 8: valid_err_rate: 0.036400% currently going ot do 10 epochs
# At minibatch 4100, batch loss 0.019471, batch error rate 0.000000%
# At minibatch 4200, batch loss 0.182664, batch error rate 4.000000%
# At minibatch 4300, batch loss 0.061963, batch error rate 3.000000%
# At minibatch 4400, batch loss 0.055605, batch error rate 1.000000%
# At minibatch 4500, batch loss 0.070935, batch error rate 2.000000%
# After epoch 9: valid_err_rate: 0.027000% currently going ot do 14 epochs
# At minibatch 4600, batch loss 0.048233, batch error rate 1.000000%
# At minibatch 4700, batch loss 0.139922, batch error rate 5.000000%
# At minibatch 4800, batch loss 0.065740, batch error rate 2.000000%
# At minibatch 4900, batch loss 0.123065, batch error rate 3.000000%
# At minibatch 5000, batch loss 0.078234, batch error rate 2.000000%
# After epoch 10: valid_err_rate: 0.032000% currently going ot do 14 epochs
# At minibatch 5100, batch loss 0.114501, batch error rate 4.000000%
# At minibatch 5200, batch loss 0.046673, batch error rate 2.000000%
# At minibatch 5300, batch loss 0.086477, batch error rate 5.000000%
# At minibatch 5400, batch loss 0.035469, batch error rate 1.000000%
# At minibatch 5500, batch loss 0.041886, batch error rate 1.000000%
# After epoch 11: valid_err_rate: 0.026400% currently going ot do 17 epochs
# At minibatch 5600, batch loss 0.074424, batch error rate 3.000000%
# At minibatch 5700, batch loss 0.036586, batch error rate 1.000000%
# At minibatch 5800, batch loss 0.049910, batch error rate 2.000000%
# At minibatch 5900, batch loss 0.026637, batch error rate 1.000000%
# At minibatch 6000, batch loss 0.081392, batch error rate 3.000000%
# After epoch 12: valid_err_rate: 0.024700% currently going ot do 19 epochs
# At minibatch 6100, batch loss 0.029658, batch error rate 0.000000%
# At minibatch 6200, batch loss 0.047322, batch error rate 1.000000%
# At minibatch 6300, batch loss 0.060820, batch error rate 2.000000%
# At minibatch 6400, batch loss 0.114544, batch error rate 3.000000%
# At minibatch 6500, batch loss 0.041809, batch error rate 1.000000%
# After epoch 13: valid_err_rate: 0.025500% currently going ot do 19 epochs
# At minibatch 6600, batch loss 0.052396, batch error rate 2.000000%
# At minibatch 6700, batch loss 0.119705, batch error rate 6.000000%
# At minibatch 6800, batch loss 0.034084, batch error rate 0.000000%
# At minibatch 6900, batch loss 0.037688, batch error rate 2.000000%
# At minibatch 7000, batch loss 0.046423, batch error rate 1.000000%
# After epoch 14: valid_err_rate: 0.026200% currently going ot do 19 epochs
# At minibatch 7100, batch loss 0.061101, batch error rate 2.000000%
# At minibatch 7200, batch loss 0.026100, batch error rate 0.000000%
# At minibatch 7300, batch loss 0.126070, batch error rate 5.000000%
# At minibatch 7400, batch loss 0.034990, batch error rate 1.000000%
# At minibatch 7500, batch loss 0.248329, batch error rate 4.000000%
# After epoch 15: valid_err_rate: 0.019800% currently going ot do 23 epochs
# At minibatch 7600, batch loss 0.024264, batch error rate 1.000000%
# At minibatch 7700, batch loss 0.026233, batch error rate 0.000000%
# At minibatch 7800, batch loss 0.073459, batch error rate 2.000000%
# At minibatch 7900, batch loss 0.053781, batch error rate 1.000000%
# At minibatch 8000, batch loss 0.096890, batch error rate 3.000000%
# After epoch 16: valid_err_rate: 0.024700% currently going ot do 23 epochs
# At minibatch 8100, batch loss 0.026669, batch error rate 1.000000%
# At minibatch 8200, batch loss 0.034907, batch error rate 0.000000%
# At minibatch 8300, batch loss 0.055411, batch error rate 2.000000%
# At minibatch 8400, batch loss 0.037966, batch error rate 1.000000%
# At minibatch 8500, batch loss 0.036750, batch error rate 1.000000%
# After epoch 17: valid_err_rate: 0.020900% currently going ot do 23 epochs
# At minibatch 8600, batch loss 0.013285, batch error rate 0.000000%
# At minibatch 8700, batch loss 0.050387, batch error rate 2.000000%
# At minibatch 8800, batch loss 0.021918, batch error rate 0.000000%
# At minibatch 8900, batch loss 0.067636, batch error rate 2.000000%
# At minibatch 9000, batch loss 0.016249, batch error rate 0.000000%
# After epoch 18: valid_err_rate: 0.021400% currently going ot do 23 epochs
# At minibatch 9100, batch loss 0.019510, batch error rate 0.000000%
# At minibatch 9200, batch loss 0.017092, batch error rate 0.000000%
# At minibatch 9300, batch loss 0.006983, batch error rate 0.000000%
# At minibatch 9400, batch loss 0.022645, batch error rate 0.000000%
# At minibatch 9500, batch loss 0.044681, batch error rate 1.000000%
# After epoch 19: valid_err_rate: 0.025900% currently going ot do 23 epochs
# At minibatch 9600, batch loss 0.057987, batch error rate 1.000000%
# At minibatch 9700, batch loss 0.077950, batch error rate 3.000000%
# At minibatch 9800, batch loss 0.027176, batch error rate 0.000000%
# At minibatch 9900, batch loss 0.041121, batch error rate 2.000000%
# At minibatch 10000, batch loss 0.022582, batch error rate 0.000000%
# After epoch 20: valid_err_rate: 0.018900% currently going ot do 31 epochs
# At minibatch 10100, batch loss 0.026605, batch error rate 0.000000%
# At minibatch 10200, batch loss 0.030779, batch error rate 0.000000%
# At minibatch 10300, batch loss 0.010700, batch error rate 0.000000%
# At minibatch 10400, batch loss 0.057843, batch error rate 3.000000%
# At minibatch 10500, batch loss 0.038808, batch error rate 2.000000%
# After epoch 21: valid_err_rate: 0.020500% currently going ot do 31 epochs
# At minibatch 10600, batch loss 0.038731, batch error rate 2.000000%
# At minibatch 10700, batch loss 0.031703, batch error rate 0.000000%
# At minibatch 10800, batch loss 0.027779, batch error rate 0.000000%
# At minibatch 10900, batch loss 0.013464, batch error rate 0.000000%
# At minibatch 11000, batch loss 0.006459, batch error rate 0.000000%
# After epoch 22: valid_err_rate: 0.019800% currently going ot do 31 epochs
# At minibatch 11100, batch loss 0.010219, batch error rate 0.000000%
# At minibatch 11200, batch loss 0.014568, batch error rate 0.000000%
# At minibatch 11300, batch loss 0.060242, batch error rate 1.000000%
# At minibatch 11400, batch loss 0.022080, batch error rate 0.000000%
# At minibatch 11500, batch loss 0.030888, batch error rate 1.000000%
# After epoch 23: valid_err_rate: 0.019900% currently going ot do 31 epochs
# At minibatch 11600, batch loss 0.034639, batch error rate 1.000000%
# At minibatch 11700, batch loss 0.015462, batch error rate 0.000000%
# At minibatch 11800, batch loss 0.011747, batch error rate 0.000000%
# At minibatch 11900, batch loss 0.023815, batch error rate 0.000000%
# At minibatch 12000, batch loss 0.009009, batch error rate 0.000000%
# After epoch 24: valid_err_rate: 0.020200% currently going ot do 31 epochs
# At minibatch 12100, batch loss 0.020921, batch error rate 0.000000%
# At minibatch 12200, batch loss 0.030167, batch error rate 1.000000%
# At minibatch 12300, batch loss 0.017925, batch error rate 0.000000%
# At minibatch 12400, batch loss 0.020627, batch error rate 0.000000%
# At minibatch 12500, batch loss 0.022303, batch error rate 0.000000%
# After epoch 25: valid_err_rate: 0.020900% currently going ot do 31 epochs
# At minibatch 12600, batch loss 0.013746, batch error rate 0.000000%
# At minibatch 12700, batch loss 0.016768, batch error rate 0.000000%
# At minibatch 12800, batch loss 0.042564, batch error rate 1.000000%
# At minibatch 12900, batch loss 0.025755, batch error rate 1.000000%
# At minibatch 13000, batch loss 0.016458, batch error rate 1.000000%
# After epoch 26: valid_err_rate: 0.020300% currently going ot do 31 epochs
# At minibatch 13100, batch loss 0.031595, batch error rate 1.000000%
# At minibatch 13200, batch loss 0.041361, batch error rate 0.000000%
# At minibatch 13300, batch loss 0.054071, batch error rate 1.000000%
# At minibatch 13400, batch loss 0.012442, batch error rate 0.000000%
# At minibatch 13500, batch loss 0.073529, batch error rate 5.000000%
# After epoch 27: valid_err_rate: 0.021800% currently going ot do 31 epochs
# At minibatch 13600, batch loss 0.043086, batch error rate 1.000000%
# At minibatch 13700, batch loss 0.015890, batch error rate 0.000000%
# At minibatch 13800, batch loss 0.069435, batch error rate 2.000000%
# At minibatch 13900, batch loss 0.035824, batch error rate 1.000000%
# At minibatch 14000, batch loss 0.082773, batch error rate 2.000000%
# After epoch 28: valid_err_rate: 0.022700% currently going ot do 31 epochs
# At minibatch 14100, batch loss 0.033438, batch error rate 1.000000%
# At minibatch 14200, batch loss 0.045899, batch error rate 1.000000%
# At minibatch 14300, batch loss 0.026273, batch error rate 1.000000%
# At minibatch 14400, batch loss 0.014878, batch error rate 0.000000%
# At minibatch 14500, batch loss 0.064720, batch error rate 1.000000%
# After epoch 29: valid_err_rate: 0.022200% currently going ot do 31 epochs
# At minibatch 14600, batch loss 0.028950, batch error rate 1.000000%
# At minibatch 14700, batch loss 0.031997, batch error rate 0.000000%
# At minibatch 14800, batch loss 0.025647, batch error rate 1.000000%
# At minibatch 14900, batch loss 0.017516, batch error rate 0.000000%
# At minibatch 15000, batch loss 0.014595, batch error rate 0.000000%
# After epoch 30: valid_err_rate: 0.020000% currently going ot do 31 epochs
# At minibatch 15100, batch loss 0.039870, batch error rate 1.000000%
# At minibatch 15200, batch loss 0.069130, batch error rate 2.000000%
# At minibatch 15300, batch loss 0.030247, batch error rate 1.000000%
# At minibatch 15400, batch loss 0.054759, batch error rate 2.000000%
# At minibatch 15500, batch loss 0.047127, batch error rate 3.000000%
# After epoch 31: valid_err_rate: 0.021500% currently going ot do 31 epochs
# Test error rate: 0.021700

# %% [markdown]
# # Problem 3 [2p bonus]
#
# Implement norm constraints, i.e. limit the total
# norm of connections incoming to a neuron. In our case, this
# corresponds to clipping the norm of *rows* of weight
# matrices. An easy way of implementing it is to make a gradient
# step, then look at the norm of rows and scale down those that are
# over the threshold (this technique is called "projected gradient descent").

# %% [markdown]
# # Problem 4 [2p bonus]
#
# Implement a **dropout** layer and try to train a
# network getting below 1.5% test error rates with dropout (the best
# result is below 1\% for dropout!). Details: http://arxiv.org/pdf/1207.0580.pdf.

# %% [markdown]
# # Problem 5 [3p bonus]
#
# Implement convolutional and max-pooling layers and (without dropout) get a test error rate below 1.5%.

# %% [markdown]
# # Problem 6 [1-3p bonus]
#
# Implement a data augmentation method (e.g. rotations, noise, crops) that will yield a significant test error rate reduction for your network. Number of bonus points depends on the ingenuity of your solution and error rate gains.
